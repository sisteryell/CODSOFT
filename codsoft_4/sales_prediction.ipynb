# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
df['TV'].hist(color='skyblue',edgecolor='black')
plt.title('Sepal Length')
plt.xlabel('cm')
plt.ylabel('Frequency')

plt.subplot(2,2,2)
df['Radio'].hist(color='lightgreen',edgecolor='black')
plt.title('Sepal Width')
plt.xlabel('cm')
plt.ylabel('Frequency')

plt.subplot(2,2,3)
df['Newspaper'].hist(color='salmon',edgecolor='black')
plt.title('Petal Length')
plt.xlabel('cm')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
sns.pairplot(df,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind='scatter')

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
x=df.drop(columns='Sales')

# %%
y=df['Sales']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=model.predict(x_test)

# %%
prediction
# Out:
# array([17.99747206, 11.02863798, 19.14207387, 15.16467067,  8.56496638,
#        10.89550601, 24.92202604, 10.61757023, 18.6998404 , 17.29854871,
#        14.66680343, 13.03094656, 19.28219899, 10.98418026, 13.7677926 ,
#        14.4988402 , 16.92235556, 17.30704485, 17.78993353, 21.29009711,
#        19.23977212, 10.98691684,  9.77272715, 11.18064352,  8.34136167,
#        13.13093624, 21.59478295, 17.04191764, 24.83365506, 11.62133637,
#        16.22765284, 21.95021111,  9.21285178,  9.94421377,  9.82032335,
#        10.22691037, 15.74967394,  9.51795157, 13.67254607, 12.42186513])

# %%
model.intercept_,model.coef_
# Out:
# (np.float64(4.576973843761907), array([0.05424164, 0.10315475, 0.00431063]))

# %%
print(f"Accuracy: {model.score(x_test,y_test)*100}")
# Out:
# Accuracy: 91.48706512256517
